# %%
import pybaseball as pyball
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pybaseball.retrosheet import *

# %%
year = 2019

example = season_game_logs(year)
example.head()
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# <ipython-input-2-d75295ab1ba6> in <module>
#       1 year = 2019
#       2
# ----> 3 example = season_game_logs(year)
#       4 example.head()
#
# ~/.local/lib/python3.8/site-packages/pybaseball/retrosheet.py in season_game_logs(season)
#     239     # validate input
#     240     g = Github(GH_TOKEN)
# --> 241     repo = g.get_repo('chadwickbureau/retrosheet')
#     242     gamelogs = [f.path[f.path.rfind('/')+1:] for f in repo.get_contents('gamelog')]
#     243     file_name = f'GL{season}.TXT'
#
# ~/.local/lib/python3.8/site-packages/github/MainClass.py in get_repo(self, full_name_or_id, lazy)
#     331                 self.__requester, {}, {"url": url}, completed=False
#     332             )
# --> 333         headers, data = self.__requester.requestJsonAndCheck(
#     334             "GET", "%s%s" % (url_base, full_name_or_id)
#     335         )
#
# ~/.local/lib/python3.8/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     315
#     316     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 317         return self.__check(
#     318             *self.requestJson(
#     319                 verb, url, parameters, headers, input, self.__customConnection(url)
#
# ~/.local/lib/python3.8/site-packages/github/Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# BadCredentialsException: 401 {"message": "Bad credentials", "documentation_url": "https://docs.github.com/rest"}

# %%
example.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-76bc54760fbe> in <module>
# ----> 1 example.head()
#
# NameError: name 'example' is not defined

# %%
pd.concat([example[example['home_team'] == 'OAK'],example[example['visiting_team'] == 'OAK']] ).sort_values('date').reset_index().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9e10294a42ef> in <module>
# ----> 1 pd.concat([example[example['home_team'] == 'OAK'],example[example['visiting_team'] == 'OAK']] ).sort_values('date').reset_index().head()
#
# NameError: name 'example' is not defined

# %%
from pybaseball import schedule_and_record
schedule_and_record(2019, "OAK")[:50]
# Out:
#                  Date   Tm Home_Away  Opp   W/L     R    RA   Inn    W-L  \
# 1   Wednesday, Mar 20  OAK      Home  SEA     L   7.0   9.0   9.0    0-1
# 2    Thursday, Mar 21  OAK      Home  SEA     L   4.0   5.0  12.0    0-2
# 3    Thursday, Mar 28  OAK      Home  LAA     W   4.0   0.0   9.0    1-2
# 4      Friday, Mar 29  OAK      Home  LAA     L   2.0   6.0   9.0    1-3
# 5    Saturday, Mar 30  OAK      Home  LAA     W   4.0   2.0   9.0    2-3
# 6      Sunday, Mar 31  OAK      Home  LAA     W   2.0   1.0   9.0    3-3
# 7       Monday, Apr 1  OAK      Home  BOS     W   7.0   0.0   9.0    4-3
# 8      Tuesday, Apr 2  OAK      Home  BOS     W   1.0   0.0   9.0    5-3
# 9    Wednesday, Apr 3  OAK      Home  BOS     L   3.0   6.0   9.0    5-4
# 10    Thursday, Apr 4  OAK      Home  BOS     W   7.0   3.0   9.0    6-4
# 11      Friday, Apr 5  OAK         @  HOU     L   2.0   3.0   9.0    6-5
# 12    Saturday, Apr 6  OAK         @  HOU     L   0.0   6.0   9.0    6-6
# 13      Sunday, Apr 7  OAK         @  HOU  L-wo   8.0   9.0   9.0    6-7
# 14      Monday, Apr 8  OAK         @  BAL     L   4.0  12.0   9.0    6-8
# 15     Tuesday, Apr 9  OAK         @  BAL     W  13.0   2.0   9.0    7-8
# 16  Wednesday, Apr 10  OAK         @  BAL     W  10.0   3.0   9.0    8-8
# 17   Thursday, Apr 11  OAK         @  BAL     W   8.0   5.0   9.0    9-8
# 18     Friday, Apr 12  OAK         @  TEX     W   8.0   6.0   9.0   10-8
# 19     Sunday, Apr 14  OAK         @  TEX     L   7.0   8.0   9.0   10-9
# 20    Tuesday, Apr 16  OAK      Home  HOU     L   1.0   9.0   9.0  10-10
# 21  Wednesday, Apr 17  OAK      Home  HOU     W   2.0   1.0   9.0  11-10
# 22     Friday, Apr 19  OAK      Home  TOR     L   1.0   5.0   9.0  11-11
# 23   Saturday, Apr 20  OAK      Home  TOR     L   1.0  10.0   9.0  11-12
# 24     Sunday, Apr 21  OAK      Home  TOR     L   4.0   5.0   9.0  11-13
# 25     Monday, Apr 22  OAK      Home  TEX     W   6.0   1.0   9.0  12-13
# 26    Tuesday, Apr 23  OAK      Home  TEX     W  11.0   5.0   9.0  13-13
# 27  Wednesday, Apr 24  OAK      Home  TEX  W-wo   6.0   5.0   9.0  14-13
# 28     Friday, Apr 26  OAK         @  TOR  L-wo   2.0   4.0   9.0  14-14
# 29   Saturday, Apr 27  OAK         @  TOR     L   1.0   7.0   9.0  14-15
# 30     Sunday, Apr 28  OAK         @  TOR  L-wo   4.0   5.0  11.0  14-16
# 31     Monday, Apr 29  OAK         @  BOS     L   4.0   9.0   9.0  14-17
# 32    Tuesday, Apr 30  OAK         @  BOS     L   1.0   5.0   9.0  14-18
# 33   Wednesday, May 1  OAK         @  BOS     L   3.0   7.0   9.0  14-19
# 34      Friday, May 3  OAK         @  PIT     W  14.0   1.0   9.0  15-19
# 35    Saturday, May 4  OAK         @  PIT     L   4.0   6.0   9.0  15-20
# 36      Sunday, May 5  OAK         @  PIT  L-wo   3.0   5.0  13.0  15-21
# 37     Tuesday, May 7  OAK      Home  CIN     W   2.0   0.0   9.0  16-21
# 38   Wednesday, May 8  OAK      Home  CIN  W-wo   5.0   4.0  13.0  17-21
# 39    Thursday, May 9  OAK      Home  CIN     L   0.0   3.0   9.0  17-22
# 40     Friday, May 10  OAK      Home  CLE  W-wo   4.0   3.0  12.0  18-22
# 41   Saturday, May 11  OAK      Home  CLE  W-wo   3.0   2.0   9.0  19-22
# 42     Sunday, May 12  OAK      Home  CLE     L   3.0   5.0   9.0  19-23
# 43     Monday, May 13  OAK         @  SEA  L-wo   5.0   6.0  10.0  19-24
# 44    Tuesday, May 14  OAK         @  SEA     L   3.0   4.0   9.0  19-25
# 45   Thursday, May 16  OAK         @  DET     W  17.0   3.0   9.0  20-25
# 46     Friday, May 17  OAK         @  DET     W   7.0   2.0   9.0  21-25
# 47   Saturday, May 18  OAK         @  DET     W   4.0   1.0   9.0  22-25
# 48     Sunday, May 19  OAK         @  DET     W   7.0   3.0   9.0  23-25
# 49     Monday, May 20  OAK         @  CLE     W   6.0   4.0   9.0  24-25
# 50    Tuesday, May 21  OAK         @  CLE     W   5.0   3.0   9.0  25-25
#
#     Rank   GB        Win        Loss        Save  Time D/N  Attendance   cLI  \
# 1    5.0  1.0   Gonzales       Fiers  Strickland  3:24   N     45787.0  1.10
# 2    5.0  2.0    Rosscup     Buchter  Strickland  4:27   N     46451.0  1.01
# 3    3.0  2.0      Fiers      Cahill        None  2:18   D     22691.0   .95
# 4    5.0  2.0     Robles       Soria        None  2:52   N     22585.0   .98
# 5    3.0  2.0   Anderson        Pena     Treinen  2:42   N     16051.0   .94
# 6    3.0  2.0     Montas      Skaggs     Treinen  2:40   D     23265.0   .98
# 7    2.0  2.0     Brooks       Price        None  2:42   N     12417.0   .92
# 8    2.0  2.0      Fiers        Sale     Treinen  2:42   N     12721.0   .98
# 9    3.0  2.5     Barnes      Rodney     Brasier  3:21   N     14207.0  1.00
# 10   3.0  2.0   Anderson   Rodriguez        None  3:16   D     15095.0   .97
# 11   3.0  2.0     McHugh      Montas       Osuna  3:03   N     43165.0  1.05
# 12   3.0  3.0      Miley      Brooks        None  2:47   N     34487.0  1.09
# 13   4.0  4.0      Osuna     Treinen        None  3:39   D     34902.0  1.02
# 14   5.0  5.0    Cashner     Estrada        None  3:07   N      6585.0   .87
# 15   4.0  5.0   Anderson       Means        None  2:53   N      7738.0   .81
# 16   4.0  5.0     Montas     Straily        None  2:35   N      7974.0   .81
# 17   3.0  5.0     Brooks       Bundy     Treinen  2:50   D      8374.0   .85
# 18   3.0  4.0    Trivino      Martin     Treinen  3:16   N     24817.0   .99
# 19   3.0  3.5    Springs       Soria     Leclerc  3:05   D     26350.0  1.04
# 20   4.0  3.5     McHugh     Estrada        None  3:03   N     12270.0  1.06
# 21   4.0  2.5     Montas       Miley     Treinen  2:29   N     11323.0  1.02
# 22   4.0  3.5    Stroman      Brooks        None  2:36   N     15128.0   .96
# 23   4.0  4.5   Gaviglio       Fiers        None  3:05   D     31140.0   .88
# 24   4.0  4.5     Hudson    Anderson       Giles  3:19   D     16015.0   .84
# 25   4.0  4.0    Bassitt       Minor        None  2:48   N      8073.0   .87
# 26   4.0  3.0     Montas        Lynn        None  3:17   N     10496.0   .94
# 27   3.0  2.5    Treinen      Martin        None  3:22   D     18610.0   .99
# 28   3.0  3.5      Giles       Petit        None  2:50   N     28688.0   .99
# 29   4.0  3.5    Sanchez    Anderson        None  2:50   D     22254.0   .95
# 30   4.0  4.0    Luciano     Treinen        None  3:56   D     18557.0   .90
# 31   4.0  4.0    Brasier      Montas      Barnes  3:23   N     30866.0   .86
# 32   4.0  5.0   Porcello      Brooks        None  2:34   N     31754.0   .77
# 33   5.0  5.0     Walden       Fiers        None  2:54   D     33708.0   .72
# 34   5.0  4.0   Anderson    Musgrove        None  3:26   N     16428.0   .68
# 35   5.0  5.0      Feliz   Wendelken     Vazquez  3:08   N     26447.0   .78
# 36   5.0  6.0      Lyons      Rodney        None  3:58   D     18517.0   .70
# 37   5.0  5.5      Fiers       Mahle        None  2:25   N     11794.0   .64
# 38   4.0  5.5   Hendriks  Stephenson        None  3:58   N      9096.0   .68
# 39   5.0  6.5      Roark     Bassitt    Iglesias  2:36   D     19694.0   .72
# 40   5.0  6.5      Soria        Hand        None  3:41   N     36913.0   .72
# 41   4.0  6.5    Treinen        Cole        None  3:13   D     18278.0   .76
# 42   4.0  7.5  Rodriguez     Mengden        Hand  2:57   D     18891.0   .77
# 43   5.0  8.5    Brennan       Soria        None  3:47   N     12514.0   .79
# 44   5.0  9.5      Leake    Anderson       Elias  2:37   N     11365.0   .70
# 45   5.0  9.5    Bassitt    Turnbull        None  2:55   D     18527.0   .55
# 46   5.0  9.5     Montas      Norris        None  2:28   N     18746.0   .62
# 47   3.0  9.5    Mengden        Boyd     Treinen  2:40   D     22913.0   .66
# 48   2.0  8.5      Fiers   Reininger        None  2:58   D     15680.0   .70
# 49   2.0  8.5   Anderson    Carrasco     Treinen  3:19   N     12563.0   .81
# 50   2.0  8.5   Hendriks       Bauer     Treinen  3:22   N     13705.0   .83
#
#     Streak Orig. Scheduled
# 1       -1            None
# 2       -2            None
# 3        1            None
# 4       -1            None
# 5        1            None
# 6        2            None
# 7        3            None
# 8        4            None
# 9       -1            None
# 10       1            None
# 11      -1            None
# 12      -2            None
# 13      -3            None
# 14      -4            None
# 15       1            None
# 16       2            None
# 17       3            None
# 18       4            None
# 19      -1            None
# 20      -2            None
# 21       1            None
# 22      -1            None
# 23      -2            None
# 24      -3            None
# 25       1            None
# 26       2            None
# 27       3            None
# 28      -1            None
# 29      -2            None
# 30      -3            None
# 31      -4            None
# 32      -5            None
# 33      -6            None
# 34       1            None
# 35      -1            None
# 36      -2            None
# 37       1            None
# 38       2            None
# 39      -1            None
# 40       1            None
# 41       2            None
# 42      -1            None
# 43      -2            None
# 44      -3            None
# 45       1            None
# 46       2            None
# 47       3            None
# 48       4            None
# 49       5            None
# 50       6            None

# %%
# teams = np.unique(season_game_logs(2019)[['home_team']])
# results = np.array((schedule_and_record(2019, "OAK").shape))
# print(teams)
# # teams = schedule_and_record(2019,ANA)
# err = []
# for team in teams:
#     print(team)
#     try:
#         np.append(results,schedule_and_record(2019, team))
#     except:
#         print(team,"didn't work")
#         err=np.append(err,team)

# %%
# results

# %% [markdown]
# There are only 19 teams in this array, there should be 30

# %%
from pybaseball import standings

# get the current season's up-to-date standings
standings()
# Out:
# [                  Tm   W   L  W-L%    GB
#  1     Tampa Bay Rays  40  20  .667    --
#  2   New York Yankees  33  27  .550   7.0
#  3  Toronto Blue Jays  32  28  .533   8.0
#  4  Baltimore Orioles  25  35  .417  15.0
#  5     Boston Red Sox  24  36  .400  16.0,
#                     Tm   W   L  W-L%    GB
#  1     Minnesota Twins  36  24  .600    --
#  2   Chicago White Sox  35  25  .583   1.0
#  3   Cleveland Indians  35  25  .583   1.0
#  4  Kansas City Royals  26  34  .433  10.0
#  5      Detroit Tigers  23  35  .397  12.0,
#                     Tm   W   L  W-L%    GB
#  1   Oakland Athletics  36  24  .600    --
#  2      Houston Astros  29  31  .483   7.0
#  3    Seattle Mariners  27  33  .450   9.0
#  4  Los Angeles Angels  26  34  .433  10.0
#  5       Texas Rangers  22  38  .367  14.0,
#                        Tm   W   L  W-L%   GB
#  1         Atlanta Braves  35  25  .583   --
#  2          Miami Marlins  31  29  .517  4.0
#  3  Philadelphia Phillies  28  32  .467  7.0
#  4          New York Mets  26  34  .433  9.0
#  5   Washington Nationals  26  34  .433  9.0,
#                      Tm   W   L  W-L%    GB
#  1         Chicago Cubs  34  26  .567    --
#  2      Cincinnati Reds  31  29  .517   3.0
#  3  St. Louis Cardinals  30  28  .517   3.0
#  4    Milwaukee Brewers  29  31  .483   5.0
#  5   Pittsburgh Pirates  19  41  .317  15.0,
#                       Tm   W   L  W-L%    GB
#  1   Los Angeles Dodgers  43  17  .717    --
#  2      San Diego Padres  37  23  .617   6.0
#  3  San Francisco Giants  29  31  .483  14.0
#  4      Colorado Rockies  26  34  .433  17.0
#  5  Arizona Diamondbacks  25  35  .417  18.0]

# %%
data.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-673852206a07> in <module>
# ----> 1 data.columns.tolist()
#
# NameError: name 'data' is not defined

# %%
copy = data.copy()
data = copy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0d5de3fed2b1> in <module>
# ----> 1 copy = data.copy()
#       2 data = copy
#
# NameError: name 'data' is not defined

# %%
# data = data[data['launch_angle'].notna()]
# data = data[data['launch_speed'].notna()]
# data = data[data['type']=='X']

# np.unique(data[['pitch_type']])
# np.unique(data[''])

# %%
data = data[data['launch_speed'].notna()]
data[['launch_speed']]

# %%
plt.scatter(data['launch_angle'],data['launch_speed'],c=data['hit_distance_sc'])
plt.xlabel("Launch angle")
plt.ylabel("Exit Velocity")
plt.xlim([-50,75])
plt.ylim([40,120])

# %%
data[data['events']=='home_run']

# %%
# # plt.hist(data[['launch_speed']])
# n_bins = 20
# unique = np.unique(data[['launch_speed']],return_counts=True)
# x = unique[0]
# y = unique[1]

# plt.hist(x,y)

# %%
np.mean(data[["launch_speed"]])

# %%
np.var(data[["launch_speed"]])

# %%
np.std(data[["launch_speed"]])

# %%
from scipy.stats import norm, kurtosis, moment, skew
from scipy import stats

# %%
kurtosis(data[["launch_speed"]])

# %%
moment(data[['launch_speed']],moment=3)

# %%
skew(data[['launch_speed']])

# %%
flat = np.array(data[['launch_speed']]).flatten()
stats.anderson(flat)

# %%
from pybaseball import statcast

# get all statcast data for July 4th, 2017
data = statcast('2017-07-04')

#get data for the first seven days of August in 2016
data = statcast('2016-08-01', '2016-08-07')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2016-08-01 to 2016-08-06
# Completed sub-query from 2016-08-07 to 2016-08-07

# %% [markdown]
# plt.hist(flat)

# %%
plt.boxplot(flat)

# %%
## NORM
mean, var = stats.distributions.norm.fit(flat)
x = np.linspace(0,120,100)
print("norm",mean,var)

fitted_data = stats.distributions.norm.pdf(x, mean, var)


plt.hist(flat, density=True)

plt.plot(x,fitted_data,'r-')
err = np.sum(np.square(np.subtract(flat,stats.distributions.norm.pdf(flat, mean,var))))
print("norm err:",err)


## EXP
mean, var = stats.distributions.expon.fit(flat)
fitted_data = stats.distributions.expon.pdf(x, mean, var)
plt.plot(x,fitted_data,'b-')
err = np.sum(np.square(np.subtract(flat,stats.distributions.pareto.pdf(flat, mean,var))))
print("exp",mean,var)
print("exp err:",err)


## Pareto

mean, var, ex= stats.distributions.pareto.fit(flat)
fitted_data = stats.distributions.pareto.pdf(x, mean, var,ex)
plt.plot(x,fitted_data,'k-')
err = np.sum(np.square(np.subtract(flat,stats.distributions.pareto.pdf(flat, mean,var))))
print("pareto",mean,var,ex)
print("pareto err:",err)

## Lognorm

mean, var, ex= stats.distributions.lognorm.fit(flat)
fitted_data = stats.distributions.lognorm.pdf(x, mean, var,ex)
plt.plot(x,fitted_data,'c_')
err = np.sum(np.square(np.subtract(flat,stats.distributions.lognorm.pdf(flat, mean,var,ex))))
print("lognorm",mean,var,ex)
print("lognorm err:",err)


## gamma
mean, var, ex= stats.distributions.gamma.fit(flat)
fitted_data = stats.distributions.gamma.pdf(x, mean, var,ex)
plt.plot(x,fitted_data,'b-')
err = np.sum(np.square(np.subtract(flat,stats.distributions.gamma.pdf(flat, mean,var,ex))))
print("gamma",mean,var,ex)
print("gamma err:",err)


## Weib
a,c,log,scale= stats.distributions.exponweib.fit(flat)
fitted_data = stats.distributions.exponweib.pdf(x, a,c,log,scale)
plt.plot(x,fitted_data,'g-')
err = np.sum(np.square(np.subtract(flat,stats.distributions.exponweib.pdf(flat, a,c,log,scale))))
print("Weib",a,c,log,scale)
print("Weib err:",err)

# %%
np.sum(np.square(np.subtract(flat,stats.distributions.exponweib.pdf(flat, a,c,log,scale))))

# %%
coef = data[['launch_angle','launch_speed','hit_distance_sc']]
coef = coef[data['launch_angle'].notna()]
coef = coef[data['launch_speed'].notna()]
coef = coef[data['hit_distance_sc'].notna()]
coef.corr()

# %%
import seaborn as sn
sn.heatmap(coef.corr(), annot=True)
plt.show()

# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
from pybaseball import statcast

# get all statcast data for July 4th, 2017
data = statcast('2017-07-04')

#get data for the first seven days of August in 2016
data = statcast('2016-08-01', '2016-08-07')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2016-08-01 to 2016-08-06
# Completed sub-query from 2016-08-07 to 2016-08-07

# %%
copy.columns.tolist()
# Out:
# ['index',
#  'pitch_type',
#  'game_date',
#  'release_speed',
#  'release_pos_x',
#  'release_pos_z',
#  'player_name',
#  'batter',
#  'pitcher',
#  'events',
#  'description',
#  'spin_dir',
#  'spin_rate_deprecated',
#  'break_angle_deprecated',
#  'break_length_deprecated',
#  'zone',
#  'des',
#  'game_type',
#  'stand',
#  'p_throws',
#  'home_team',
#  'away_team',
#  'type',
#  'hit_location',
#  'bb_type',
#  'balls',
#  'strikes',
#  'game_year',
#  'pfx_x',
#  'pfx_z',
#  'plate_x',
#  'plate_z',
#  'on_3b',
#  'on_2b',
#  'on_1b',
#  'outs_when_up',
#  'inning',
#  'inning_topbot',
#  'hc_x',
#  'hc_y',
#  'tfs_deprecated',
#  'tfs_zulu_deprecated',
#  'fielder_2',
#  'umpire',
#  'sv_id',
#  'vx0',
#  'vy0',
#  'vz0',
#  'ax',
#  'ay',
#  'az',
#  'sz_top',
#  'sz_bot',
#  'hit_distance_sc',
#  'launch_speed',
#  'launch_angle',
#  'effective_speed',
#  'release_spin_rate',
#  'release_extension',
#  'game_pk',
#  'pitcher.1',
#  'fielder_2.1',
#  'fielder_3',
#  'fielder_4',
#  'fielder_5',
#  'fielder_6',
#  'fielder_7',
#  'fielder_8',
#  'fielder_9',
#  'release_pos_y',
#  'estimated_ba_using_speedangle',
#  'estimated_woba_using_speedangle',
#  'woba_value',
#  'woba_denom',
#  'babip_value',
#  'iso_value',
#  'launch_speed_angle',
#  'at_bat_number',
#  'pitch_number',
#  'pitch_name',
#  'home_score',
#  'away_score',
#  'bat_score',
#  'fld_score',
#  'post_away_score',
#  'post_home_score',
#  'post_bat_score',
#  'post_fld_score',
#  'if_fielding_alignment',
#  'of_fielding_alignment']

# %%
copy = data
copy = copy[copy['launch_angle'].notna()]
copy = copy[copy['launch_speed'].notna()]
copy = copy[copy['hit_distance_sc'].notna()]

target = copy.pop('hit_distance_sc')
input_data = copy[['launch_angle','launch_speed']]
input_data
# Out:
#        launch_angle  launch_speed
# 0              10.0          77.1
# 1              -7.0          93.7
# 6              55.0          85.3
# 9              37.0          96.3
# 11             14.0          99.7
# ...             ...           ...
# 28016          30.0          89.5
# 28021          11.0          64.4
# 28031           7.0          99.7
# 28034          -9.0         101.6
# 28041          60.0          85.6
#
# [4469 rows x 2 columns]

# %%
dataset = tf.data.Dataset.from_tensor_slices((input_data.values, target.values))

for feat, targ in dataset.take(5):
  print('Features: {}, Target: {}'.format(feat, targ))
# Out:
# Features: [10.  77.1], Target: 114.0
# Features: [-7.  93.7], Target: 23.0
# Features: [55.  85.3], Target: 200.0
# Features: [37.  96.3], Target: 350.0
# Features: [14.  99.7], Target: 324.0

# %%
tf.constant(copy['launch_angle'])
# Out:
# <tf.Tensor: shape=(4469,), dtype=float64, numpy=array([10., -7., 55., ...,  7., -9., 60.])>

# %%
train_dataset = dataset.shuffle(len(copy)).batch(1)

# %%
def get_compiled_model():
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
  ])

  model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
  return model

# %%
model = get_compiled_model()
model.fit(train_dataset, epochs=15)
# Out:
# Epoch 1/15
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 4469/4469 [==============================] - 5s 1ms/step - loss: -34694008.0000 - accuracy: 6.7129e-04
# Epoch 2/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -376730624.0000 - accuracy: 6.7129e-04
# Epoch 3/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -1303343104.0000 - accuracy: 6.7129e-04
# Epoch 4/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -3134210304.0000 - accuracy: 6.7129e-04
# Epoch 5/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -6118501888.0000 - accuracy: 6.7129e-04
# Epoch 6/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -10549916672.0000 - accuracy: 6.7129e-04
# Epoch 7/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -16651535360.0000 - accuracy: 6.7129e-04
# Epoch 8/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -24703469568.0000 - accuracy: 6.7129e-04
# Epoch 9/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -34886266880.0000 - accuracy: 6.7129e-04
# Epoch 10/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -47503839232.0000 - accuracy: 6.7129e-04
# Epoch 11/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -62772928512.0000 - accuracy: 6.7129e-04
# Epoch 12/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -81062060032.0000 - accuracy: 6.7129e-04
# Epoch 13/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -102377684992.0000 - accuracy: 6.7129e-04
# Epoch 14/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -127172861952.0000 - accuracy: 6.7129e-04
# Epoch 15/15
# 4469/4469 [==============================] - 5s 1ms/step - loss: -155501133824.0000 - accuracy: 6.7129e-04

# %%
model.de
